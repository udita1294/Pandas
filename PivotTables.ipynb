# %%
import numpy as np
import pandas as pd

# %% [markdown]
# PIVOT TABLES

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    671     95   John  January      Q1
# 1  2023-01-02       B   West    594     68   Mary  January      Q1
# 2  2023-01-03       C  North    829     37    Bob  January      Q1
# 3  2023-01-04       D  South    795     78  Alice  January      Q1
# 4  2023-01-05       A   East    835     23   John  January      Q1
# 5  2023-01-06       B   West    538     54   Mary  January      Q1
# 6  2023-01-07       C  North    657     42    Bob  January      Q1
# 7  2023-01-08       D  South    877     99  Alice  January      Q1
# 8  2023-01-09       A   East    119     23   John  January      Q1
# 9  2023-01-10       B   West    988     22   Mary  January      Q1
# 10 2023-01-11       C  North    228     70    Bob  January      Q1
# 11 2023-01-12       D  South    250     60  Alice  January      Q1
# 12 2023-01-13       A   East    257     19   John  January      Q1
# 13 2023-01-14       B   West    778     85   Mary  January      Q1
# 14 2023-01-15       C  North    107     24    Bob  January      Q1
# 15 2023-01-16       D  South    659     48  Alice  January      Q1
# 16 2023-01-17       A   East    594     99   John  January      Q1
# 17 2023-01-18       B   West    412     77   Mary  January      Q1
# 18 2023-01-19       C  North    158     44    Bob  January      Q1
# 19 2023-01-20       D  South    230     66  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index='Region',columns='Product',aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     594.0    NaN    NaN    NaN
# North      NaN    NaN  228.0    NaN
# South      NaN    NaN    NaN  659.0
# West       NaN  594.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=['Sales','Units'],index='Region',columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     495.2    NaN    NaN    NaN  51.8   NaN   NaN   NaN
# North      NaN    NaN  395.8    NaN   NaN   NaN  43.4   NaN
# South      NaN    NaN    NaN  562.2   NaN   NaN   NaN  70.2
# West       NaN  662.0    NaN    NaN   NaN  61.2   NaN   NaN

# %% [markdown]
# CROSS TABS

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
